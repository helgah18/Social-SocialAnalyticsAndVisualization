# %% [markdown]
# ## Social data analytics and visualization Final project

# %%
In
# Out:
# ['', 'In ']

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
housing_df = pd.read_csv("nyc_housing.csv") 
housing_df
# Out:
#            areaName    Borough      areaType        Date  Sales_Price  \
# 0      All Downtown  Manhattan     submarket  2010-01-01     900000.0
# 1      All Downtown  Manhattan     submarket  2010-02-01     849500.0
# 2      All Downtown  Manhattan     submarket  2010-03-01     990000.0
# 3      All Downtown  Manhattan     submarket  2010-04-01     992793.0
# 4      All Downtown  Manhattan     submarket  2010-05-01     916962.0
# ...             ...        ...           ...         ...          ...
# 28757     Woodstock      Bronx  neighborhood  2021-10-01          NaN
# 28758     Woodstock      Bronx  neighborhood  2021-11-01          NaN
# 28759     Woodstock      Bronx  neighborhood  2021-12-01     350000.0
# 28760     Woodstock      Bronx  neighborhood  2022-01-01          NaN
# 28761     Woodstock      Bronx  neighborhood  2022-02-01          NaN
#
#        Asking_Price  Days_in_market  Volume_sold
# 0         1399000.0             121          291
# ...

# %%
len(housing_df['areaName'].value_counts())
# Out:
# 197

# %%
housing_df['Borough'].value_counts().sort_values(ascending=False).plot(kind = 'bar', color=sns.color_palette() \
                        ,figsize=(10, 10), title='Number of houses sold in each Borough')
# Out:
# <AxesSubplot:title={'center':'Number of houses sold in each Borough'}>

# %%
housing_df.groupby(['areaName']).mean()['Sales_Price'].sort_values(ascending=False)[:20]
# Out:
# areaName
# Tribeca                3.138858e+06
# Soho                   2.409176e+06
# Flatiron               1.660468e+06
# Central Park South     1.626101e+06
# Midtown                1.504545e+06
# DUMBO                  1.427918e+06
# Boerum Hill            1.409742e+06
# Carroll Gardens        1.366849e+06
# Cobble Hill            1.365506e+06
# West Village           1.257395e+06
# Greenwich Village      1.238968e+06
# Manhattan Beach        1.225000e+06
# All Downtown           1.222259e+06
# Chelsea                1.134647e+06
# Battery Park City      1.089749e+06
# All Upper West Side    1.079336e+06
# Upper West Side        1.079336e+06
# Park Slope             1.061038e+06
# Upper East Side        1.041108e+06
# All Upper East Side    1.041108e+06
# Name: Sales_Price, dtype: float64

# %%
housing_df.groupby(['areaName']).mean()['Sales_Price'].sort_values(ascending=True)[:20]
# Out:
# areaName
# Morrisania             26000.000000
# Parkchester           136138.585714
# Woodlawn              259595.000000
# Briarwood             260755.693694
# Kew Gardens           262601.852113
# Kew Gardens Hills     272475.645833
# University Heights    272829.687500
# Riverdale             279339.561644
# Oakland Gardens       283534.211268
# Clearview             287329.110000
# Rego Park             306174.369863
# Concourse             310623.000000
# Howard Beach          313488.986301
# Kingsbridge           344789.321429
# Forest Hills          344923.767123
# Bronxwood             347275.135135
# Crotona Park East     347284.714286
# Glen Oaks             358806.013793
# Inwood                359510.280000
# Little Neck           364985.382353
# Name: Sales_Price, dtype: float64

# %%
#housing_df['areaName'].value_counts().sort_values(ascending=False).plot(kind = 'bar', color=sns.color_palette()\
#                    ,figsize=(13, 9), title='Number of houses sold in each area')

# %%
housing_df.groupby(['Borough']).mean()['Sales_Price']\
        .plot(kind='bar', color=sns.color_palette(),figsize=(10, 9), \
        title='Average price of housing in different neighbourhoods');

# %%
water_comp_data = pd.read_csv('YOY_Water_Complaints.csv')
# Out:
# /Users/helgahalldorsdottir/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
water_comp_data
# Out:
#        Unique Key  Created Date             Closed Date Agency  \
# 0        50475280          2021  06/30/2021 12:00:00 AM    DEP
# 1        50477390          2021  06/30/2021 12:00:00 AM    DEP
# 2        50477428          2021  05/06/2021 09:16:00 AM    DEP
# 3        45005686          2019  11/25/2019 01:00:00 PM    DEP
# 4        44167911          2019  01/03/2020 02:16:00 PM    DEP
# ...           ...           ...                     ...    ...
# 17952    51895609          2021  09/20/2021 06:43:00 AM    DEP
# 17953    51899389          2021  10/18/2021 10:04:00 AM    DEP
# 17954    51901180          2021  09/20/2021 06:48:00 AM    DEP
# 17955    51911831          2021  09/20/2021 09:37:00 AM    DEP
# 17956    51913103          2021  09/20/2021 10:31:00 AM    DEP
#
#                                   Agency Name Complaint Type  \
# 0      Department of Environmental Protection  Water Quality
# 1      Department of Environmental Protection  Water Quality
# ...

# %%
air_qual_data = pd.read_csv('Air_Quality.csv')
air_qual_data['Geo Place Name'].value_counts()
# Out:
# Ridgewood - Forest Hills              214
# Pelham - Throgs Neck                  214
# Canarsie - Flatlands                  214
# Bedford Stuyvesant - Crown Heights    214
# Greenpoint                            214
#                                      ...
# Union Square-Lower Manhattan           79
# Upper East Side-Gramercy               79
# Chelsea-Village                        79
# Southern SI                            79
# Bayside Little Neck-Fresh Meadows      79
# Name: Geo Place Name, Length: 114, dtype: int64

# %%
air_qual_data
# Out:
#        Unique ID  Indicator ID                                     Name  \
# 0         333939           365          Fine Particulate Matter (PM2.5)
# 1         547354           365          Fine Particulate Matter (PM2.5)
# 2         605650           365          Fine Particulate Matter (PM2.5)
# 3         179503           365          Fine Particulate Matter (PM2.5)
# 4         179643           365          Fine Particulate Matter (PM2.5)
# ...          ...           ...                                      ...
# 14284     131167           655  O3-Attributable Asthma Hospitalizations
# 14285     518596           655  O3-Attributable Asthma Hospitalizations
# 14286     151571           655  O3-Attributable Asthma Hospitalizations
# 14287     628961           655  O3-Attributable Asthma Hospitalizations
# 14288     131168           655  O3-Attributable Asthma Hospitalizations
#
#                                                Measure          Measure Info  \
# ...

# %%
water_data = pd.read_csv('nyc_water.csv')
water_data
# Out:
#                Date  Average 24hrTurbidity(NTU)  Coliform, Fecal(fc/100mL)  \
# 0        2010-01-01                         NaN                        NaN
# 1        2010-01-01                         NaN                        NaN
# 2        2010-01-01                         NaN                        NaN
# 3        2010-01-01                         NaN                        NaN
# 4        2010-01-01                         NaN                        NaN
# ...             ...                         ...                        ...
# 4568299  2022-04-06                         NaN                        NaN
# 4568300  2022-04-07                         NaN                        NaN
# 4568301  2022-04-07                         NaN                        NaN
# 4568302  2022-04-07                         NaN                        NaN
# 4568303  2022-04-07                         NaN                        NaN
#
# ...

# %%
df = pd.read_csv('df.csv')
df.columns
# Out:
# Index(['Unnamed: 0', 'BOROUGH\n', 'NEIGHBORHOOD\n',
#        'BUILDING CLASS CATEGORY\n', 'TAX CLASS AT PRESENT\n', 'BLOCK\n',
#        'LOT\n', 'EASE-MENT\n', 'BUILDING CLASS AT PRESENT\n', 'ADDRESS\n',
#        'APARTMENT NUMBER\n', 'ZIP CODE\n', 'RESIDENTIAL UNITS\n',
#        'COMMERCIAL UNITS\n', 'TOTAL UNITS\n', 'LAND SQUARE FEET\n',
#        'GROSS SQUARE FEET\n', 'YEAR BUILT\n', 'TAX CLASS AT TIME OF SALE\n',
#        'BUILDING CLASS AT TIME OF SALE\n', 'SALE PRICE\n', 'SALE DATE\n',
#        'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE', 'TAX CLASS AS OF FINAL ROLL 17/18',
# ...

# %%
df[['BOROUGH\n', 'SALE DATE\n']]
# Out:
#         BOROUGH\n SALE DATE\n
# 0             5.0  2014-12-08
# 1             5.0  2014-07-17
# 2             5.0  2014-05-30
# 3             5.0  2014-07-29
# 4             5.0  2014-06-17
# ...           ...         ...
# 606174        1.0  2014-04-22
# 606175        1.0  2014-06-04
# 606176        1.0  2014-06-16
# 606177        1.0  2014-07-07
# 606178        1.0  2014-10-03
#
# [606179 rows x 2 columns]

# %%
df[df['SALE DATE'].notna()]['SALE DATE'].sort_values()
# Out:
# 120250    2011-01-01
# 553791    2011-01-01
# 163015    2011-01-01
# 131691    2011-01-01
# 165577    2011-01-01
#              ...
# 130328    2011-12-31
# 121235    2011-12-31
# 326738    2011-12-31
# 170529    2011-12-31
# 121102    2011-12-31
# Name: SALE DATE, Length: 73525, dtype: object

# %%
df[df['SALE DATE\n'].notna()]['SALE DATE\n'].sort_values()
# Out:
# 209268    2012-01-01
# 186166    2012-01-01
# 211143    2012-01-01
# 201348    2012-01-01
# 202712    2012-01-01
#              ...
# 266051    2017-12-31
# 455031    2017-12-31
# 533112    2017-12-31
# 266050    2017-12-31
# 471717    2017-12-31
# Name: SALE DATE\n, Length: 532654, dtype: object

# %%
df = df[['BOROUGH','NEIGHBORHOOD','ZIP CODE','SALE PRICE','SALE DATE']]#did not find asking price?
housing_df_cl = df[df['ZIP CODE'].notna()]
#drop columns with sales price 0
housing_df_cl = housing_df_cl[housing_df_cl['SALE PRICE'] != 0]
housing_df_cl.reset_index()

housing_df_cl
# Out:
#         BOROUGH               NEIGHBORHOOD  ZIP CODE  SALE PRICE   SALE DATE
# 114989      1.0  ALPHABET CITY               10009.0        10.0  2011-08-26
# 114991      1.0  ALPHABET CITY               10009.0   3500000.0  2011-09-08
# 114992      1.0  ALPHABET CITY               10009.0   2966835.0  2011-07-25
# 114996      1.0  ALPHABET CITY               10009.0   1400000.0  2011-01-31
# 114997      1.0  ALPHABET CITY               10009.0    800000.0  2011-01-31
# ...         ...                        ...       ...         ...         ...
# 556123      3.0  WYCKOFF HEIGHTS             11237.0   2375000.0  2011-12-14
# 556124      3.0  WYCKOFF HEIGHTS             11237.0    900000.0  2011-05-12
# 556126      3.0  WYCKOFF HEIGHTS             11237.0   1300000.0  2011-11-22
# 556133      3.0  WYCKOFF HEIGHTS             11237.0    450000.0  2011-10-24
# 556134      3.0  WYCKOFF HEIGHTS             11237.0    275000.0  2011-08-10
#
# [50493 rows x 5 columns]

# %%
water_comp_data_cl = water_comp_data[water_comp_data['Incident Zip'].notna()]
water_comp_data_cl['Incident Zip'].sort_values(ascending=False)
water_comp_data_cl = water_comp_data_cl.rename(columns = {'Incident Zip':'ZIP CODE'})
water_comp_data_cl = water_comp_data_cl[['ZIP CODE','Created Date', 'Agency','City','Landmark','Facility Type','Borough','Location']]

water_comp_data_cl
# Out:
#        ZIP CODE  Created Date Agency           City  Landmark  Facility Type  \
# 0       11234.0          2021    DEP       BROOKLYN       NaN            NaN
# 1       11219.0          2021    DEP       BROOKLYN       NaN            NaN
# 2       10033.0          2021    DEP       NEW YORK       NaN            NaN
# 3       10026.0          2019    DEP       NEW YORK       NaN            NaN
# 4       10305.0          2019    DEP  STATEN ISLAND       NaN            NaN
# ...         ...           ...    ...            ...       ...            ...
# 17952   11356.0          2021    DEP  College Point       NaN            NaN
# 17953   10006.0          2021    DEP       NEW YORK       NaN            NaN
# 17954   10037.0          2021    DEP       NEW YORK       NaN            NaN
# 17955   10463.0          2021    DEP          BRONX       NaN            NaN
# 17956   11205.0          2021    DEP       BROOKLYN       NaN            NaN
#
# ...

# %%
#len(pd.concat([water_comp_data_cl, housing_df_cl], keys =['ZIP CODE'], axis = 1))
#pd.concat([water_comp_data_cl, housing_df_cl], keys =['ZIP CODE'], axis = 1)

# %%
merged = pd.merge(water_comp_data_cl, housing_df_cl,how ='left', on='ZIP CODE')
merged
# Out:
#          ZIP CODE  Created Date Agency      City  Landmark  Facility Type  \
# 0         11234.0          2021    DEP  BROOKLYN       NaN            NaN
# 1         11234.0          2021    DEP  BROOKLYN       NaN            NaN
# 2         11234.0          2021    DEP  BROOKLYN       NaN            NaN
# 3         11234.0          2021    DEP  BROOKLYN       NaN            NaN
# 4         11234.0          2021    DEP  BROOKLYN       NaN            NaN
# ...           ...           ...    ...       ...       ...            ...
# 6299600   11205.0          2021    DEP  BROOKLYN       NaN            NaN
# 6299601   11205.0          2021    DEP  BROOKLYN       NaN            NaN
# 6299602   11205.0          2021    DEP  BROOKLYN       NaN            NaN
# 6299603   11205.0          2021    DEP  BROOKLYN       NaN            NaN
# 6299604   11205.0          2021    DEP  BROOKLYN       NaN            NaN
#
#           Borough                                 Location  BOROUGH  \
# ...

# %%
merged.drop_duplicates()
# Out:
#          ZIP CODE  Created Date Agency      City  Landmark  Facility Type  \
# 0         11234.0          2021    DEP  BROOKLYN       NaN            NaN
# 1         11234.0          2021    DEP  BROOKLYN       NaN            NaN
# 2         11234.0          2021    DEP  BROOKLYN       NaN            NaN
# 3         11234.0          2021    DEP  BROOKLYN       NaN            NaN
# 4         11234.0          2021    DEP  BROOKLYN       NaN            NaN
# ...           ...           ...    ...       ...       ...            ...
# 6299600   11205.0          2021    DEP  BROOKLYN       NaN            NaN
# 6299601   11205.0          2021    DEP  BROOKLYN       NaN            NaN
# 6299602   11205.0          2021    DEP  BROOKLYN       NaN            NaN
# 6299603   11205.0          2021    DEP  BROOKLYN       NaN            NaN
# 6299604   11205.0          2021    DEP  BROOKLYN       NaN            NaN
#
#           Borough                                 Location  BOROUGH  \
# ...

# %%
merged.groupby()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-626c99e4bb44> in <module>
# ----> 1 merged.groupby()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6712
#    6713         if level is None and by is None:
# -> 6714             raise TypeError("You have to supply one of 'by' and 'level'")
#    6715         axis = self._get_axis_number(axis)
#    6716
#
# TypeError: You have to supply one of 'by' and 'level'
